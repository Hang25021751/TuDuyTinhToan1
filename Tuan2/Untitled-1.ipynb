# %%
n = int(input("nhap vao so nguyen n:"))
print(f"so gap doi cua n la:{2*n}")
# Out:
# so gap doi cua n la:12

# %%
a = float(input("nhap vao chieu rong:"))
b = float(input("nhap vao chieu dai:"))
# dien tich hinh chu nhat:
s1 = a*b 
# dien tich hinh tron
s2 = 3.14*(a/2)**2
# dien tich xung quanh de trong cay
s3 = s1-s2 
print(f"dien tich xung quanh de trong cay la:{s3:.2f}")
# Out:
# dien tich xung quanh de trong cay la:25.38

# %%
c = input("nhap vao mot ki tu c:")
if 65<=ord(c)<=90: 
    a = c.lower()
    print(f"chu cai thuong tuong  ung la:{a}")
elif 97 <=ord(c)<=122:
    b = c.upper()
    print(f"chu cai hoa tuong ung la:{b}")
else:
    print("khong phai la chu cai")
# Out:
# chu cai thuong tuong  ung la:k

# %%
x = input("nhap vao mot ki tu:").strip()
if len(x)==1 and x.isalpha():
    print("x la chu cai alphabet")
else:
    print("x khong phai la chu cai alphabet")
# Out:
# x la chu cai alphabet

# %%
x = input("nhap vao chu cai in hoa:")
if 66<= ord(x)<= 90:
    m = x.lower()
    y = chr(ord(m)-1)
    print(f"chu cai thuong lien truoc:{y}")
elif x == "A":
    print("chu cai thuong lien truoc la:z")
else :
    print("khong phai chu cai hoa")
# Out:
# chu cai thuong lien truoc la:z

# %%
a,b,c = map(float,input("nhap vao ba canh cua tam giac:").split())
import math 
if a+b>c and a+c>b and b+c>a :
    p = (a+b+c)/2 
    d = p*2 
    s = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print(f" dien tich cua tam giac la:{s:.1f}")
    print(f"chu vi cua tam giac la:{d}")
else:
    print("khong phai ba canh cua tam giac")
# Out:
# khong phai ba canh cua tam giac

# %%
x = input("nhap vao mot chuoi ki tu:")
if len(x)>=20:
    print("chu cai thu nam la:" ,x[4])
    print("chu cai thu chin la:" ,x[8])
else:
    print("chuoi ki tu khong thoa man")
# Out:
# chuoi ki tu khong thoa man

# %%
ten_chu_ho = input("nhap vao ten chu ho")
# chi so dien thang nay
c1= int(input("nhap vao chi so dien thang truoc"))
# chi so dien thang truoc
c2= int(input("nhap vao chi so dien  thang nay"))
# tien dien thang nay
x = int(input("nhap vao gia dien tren mot so:")) # don vi dong 
t= (c2-c1)* x *1.08
print("tien dien thang nay la", round(t))
# Out:
# tien dien thang nay la 2189765
